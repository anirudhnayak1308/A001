# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudhnayak1308/Netzwerk/blob/main/EDA_football.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fifa = pd.read_csv('/content/players_20.csv')
fifa.head()
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  53+3  61+3
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...  ...  46+3  61+3
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...  ...   NaN   NaN
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
#
# [5 rows x 104 columns]

# %%
fifa.shape
# Out:
# (2019, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# Spain            511
# Brazil           445
# England          438
# France           410
# Germany          387
#                 ...
# Afghanistan        1
# Faroe Islands      1
# Thailand           1
# Uzbekistan         1
# Mauritania         1
# Name: nationality, Length: 133, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# Spain          511
# Brazil         445
# England        438
# France         410
# Germany        387
# Argentina      387
# Italy          272
# Portugal       179
# Colombia       172
# Netherlands    160
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['Spain', 'Brazil', 'England', 'France', 'Germany'], dtype='object')

# %%
plt.figure(figsize=(8,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color='g')
plt.show()

# %%
p_salary = fifa[['short_name','wage_eur']]

# %%
p_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
p_salary = p_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
p_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi  565000.0
# 4           E. Hazard  470000.0
# 1   Cristiano Ronaldo  405000.0
# 22       A. Griezmann  370000.0
# 5        K. De Bruyne  370000.0

# %%
p_lsalary = p_salary.sort_values(by=['wage_eur'],ascending=True)

# %%
p_lsalary.head()
# Out:
#          short_name  wage_eur
# 1612    A. Zamorado       0.0
# 749      D. Lenzado       0.0
# 3697  G. Chatterjee       0.0
# 567        M. Nérez       0.0
# 750      E. Riquero       0.0

# %%
plt.figure(figsize=(8,5))
plt.bar(list(p_salary['short_name'])[0:5],list(p_salary['wage_eur'])[0:5],color=['blue','green','red','pink','orange'])
plt.show()

# %%
fifa['nationality'] == 'Spain'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2014    False
# 2015    False
# 2016    False
# 2017    False
# 2018    False
# Name: nationality, Length: 2019, dtype: bool

# %%
spain = fifa[fifa['nationality'] == 'Spain']
spain.head(10)
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 14     193080  https://sofifa.com/player/193080/david-de-gea-...  ...   NaN   NaN
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 21     189511  https://sofifa.com/player/189511/sergio-busque...  ...  82+3  78+3
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...  ...  85+3  78+3
# 33     168542  https://sofifa.com/player/168542/david-josue-j...  ...  56+3  63+3
# 51     189332  https://sofifa.com/player/189332/jordi-alba-ra...  ...  78+3  84+3
# 52     189509  https://sofifa.com/player/189509/thiago-alcant...  ...  69+3  75+3
# 62     197781  https://sofifa.com/player/197781/francisco-rom...  ...  62+3  67+3
# 69     189513  https://sofifa.com/player/189513/daniel-parejo...  ...  69+2  71+2
# 79     231866  https://sofifa.com/player/231866/rodrigo-herna...  ...  80+2  78+2
#
# [10 rows x 104 columns]

# %%
spain.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  ...   rcb    rb
# 492      146748  https://sofifa.com/player/146748/diego-lopez-r...  ...   NaN   NaN
# 842      195668  https://sofifa.com/player/195668/joel-robles-b...  ...   NaN   NaN
# 29       152729  https://sofifa.com/player/152729/gerard-pique-...  ...  85+3  78+3
# 1101     206652  https://sofifa.com/player/206652/sergio-rico-g...  ...   NaN   NaN
# 14       193080  https://sofifa.com/player/193080/david-de-gea-...  ...   NaN   NaN
#
# [5 rows x 104 columns]

# %%
spain.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  ...  rcb   rb
# 1174     183666  https://sofifa.com/player/183666/roberto-jimen...  ...  NaN  NaN
# 286       24630  https://sofifa.com/player/24630/jose-manuel-re...  ...  NaN  NaN
# 386      178086  https://sofifa.com/player/178086/antonio-adan-...  ...  NaN  NaN
# 842      195668  https://sofifa.com/player/195668/joel-robles-b...  ...  NaN  NaN
# 1101     206652  https://sofifa.com/player/206652/sergio-rico-g...  ...  NaN  NaN
#
# [5 rows x 104 columns]

# %%
spain.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 21     189511  https://sofifa.com/player/189511/sergio-busque...  ...  82+3  78+3
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...  ...  85+3  78+3
# 33     168542  https://sofifa.com/player/168542/david-josue-j...  ...  56+3  63+3
# 62     197781  https://sofifa.com/player/197781/francisco-rom...  ...  62+3  67+3
#
# [5 rows x 104 columns]

# %%
spain[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head(10)
# Out:
#           short_name  wage_eur
# 21   Sergio Busquets    300000
# 18      Sergio Ramos    300000
# 29             Piqué    285000
# 33       David Silva    265000
# 62              Isco    245000
# 51        Jordi Alba    240000
# 14            De Gea    205000
# 94          Carvajal    205000
# 52            Thiago    180000
# 403    Lucas Vázquez    180000

# %%
defender = fifa[['short_name','defending','nationality','club']]
defender.head(3)
# Out:
#           short_name  defending nationality                 club
# 0           L. Messi       39.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo       35.0    Portugal             Juventus
# 2          Neymar Jr       32.0      Brazil  Paris Saint-Germain

# %%
defender.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 16  G. Chiellini       90.0        Italy           Juventus
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 49    M. Hummels       89.0      Germany  Borussia Dortmund
# 35      D. Godín       89.0      Uruguay              Inter

# %%
rm = fifa[fifa['club']=='Real Madrid']

# %%
rm.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...  ...  72+3  79+3
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 46     165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
#
# [5 rows x 104 columns]

# %%
rm['nationality'].value_counts()
rm
# Out:
#       sofifa_id                                         player_url  ...   rcb    rb
# 4        183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 8        177003  https://sofifa.com/player/177003/luka-modric/2...  ...  72+3  79+3
# 18       155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 28       192119  https://sofifa.com/player/192119/thibaut-court...  ...   NaN   NaN
# 36       182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 42       200145  https://sofifa.com/player/200145/carlos-henriq...  ...  84+3  79+3
# 46       165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
# 53       193041  https://sofifa.com/player/193041/keylor-navas/...  ...   NaN   NaN
# 62       197781  https://sofifa.com/player/197781/francisco-rom...  ...  62+3  67+3
# 76       201535  https://sofifa.com/player/201535/raphael-varan...  ...  83+3  77+3
# ...
